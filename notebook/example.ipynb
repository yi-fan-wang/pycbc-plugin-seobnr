# %%
import sys
import matplotlib.pyplot as plt

# %%
sys.path.append('../')

# %%
from plugin import genwave

# %%
par = {'mass1':30,
       'mass2':30,
       'spin1x':0,
       'spin1y':0,
       'spin1z':0,
       'spin2x':0,
       'spin2y':0,
       'spin2z':0,
       'distance':300,
       'inclination':0.1,
       'delta_t':1/1024,
       'f_lower':20,
       'coa_phase':0,
       'eccentricity':0.1,
       'rel_anomaly':0}

# %%
hp,hc = genwave.genwave(**par)

# %%
plt.plot(hp.sample_times,hp)
